# %% [markdown]
# ## Timeseries Homework

# %%
# Dependencies and modules:

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import statistics
import math
from scipy import stats
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf


# temperature.csv file:

temperature_path = "C:/Users/Nik/Documents/temperature.csv"
temperature_df = pd.read_csv(temperature_path,parse_dates=True, index_col='datetime')

temperature_df.head(1)
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2012-10-01 12:00:00        NaN       NaN            NaN      NaN          NaN
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2012-10-01 12:00:00        NaN        NaN      NaN          NaN     NaN  ...
#
#                      Philadelphia  New York  Montreal  Boston  Beersheba  \
# datetime
# 2012-10-01 12:00:00           NaN       NaN       NaN     NaN        NaN
#
#                      Tel Aviv District  Eilat  Haifa  Nahariyya  Jerusalem
# datetime
# 2012-10-01 12:00:00                NaN  309.1    NaN        NaN        NaN
#
# [1 rows x 36 columns]

# %% [markdown]
# 1. What scale of measurement applies to timeseries data? Is timeseries data continuous or discrete? Why?

# %% [markdown]
# Timeseries data can be either continuous or discrete depending on the data you are working with. You could have discrete timeseries data with timestamps referring to user logins or irregular events. Time series data can be continuous if you are working with timestamps that break units of time up into floating point values, such as when using fractions of a minute or seconds.

# %% [markdown]
# 2. What does ARIMA stand for? Break down and explain each piece in the name.

# %% [markdown]
# ARIMA stands for auto-regressive integrated moving average. Autoregression is a model that predicts future values based on past values. "Integrated" represents differencing the raw observations to allow for the time series to become stationary. And finally, moving average incorporates the dependency between an observation and a residual error from a moving average model applied to lagged observations.

# %% [markdown]
# 3. Using the data in the temperatures/ folder. Write a function that efficiently converts every column to a different temperature scale: one that is more common than Kelvin.

# %%
# I will convert to Celsius with following function:
def Kelvin_to_Celsius(city,scale='C'):
    """Function converts the the df temp in Kelvin to Celsius"""
    try:
        if scale == 'C':
            city = city - 273.15
        else:
            print("Scale should either be Celsius(C)")
    except Exception as e:
        print(e)
    return city

# %%
temperature_df_Celsius = pd.DataFrame(index=temperature_df.index)

for col in temperature_df.columns:
    temperature_df_Celsius[col] = Kelvin_to_Celsius(temperature_df[col],scale='C')
#I don't know what "unsupported operand type(s) for -: 'str' and 'floa.t" means, but code worked, so I am moving on

# %%
temperature_df_Celsius.head()
# Out:
#                      Vancouver  Portland  San Francisco   Seattle  \
# datetime
# 2012-10-01 12:00:00        NaN       NaN            NaN       NaN
# 2012-10-01 13:00:00  11.480000  8.930000      16.330000  8.650000
# 2012-10-01 14:00:00  11.479041  8.933252      16.324993  8.647217
# 2012-10-01 15:00:00  11.476998  8.941867      16.310618  8.639833
# 2012-10-01 16:00:00  11.474955  8.950481      16.296243  8.632449
#
#                      Los Angeles  San Diego  Las Vegas    Phoenix  \
# datetime
# 2012-10-01 12:00:00          NaN        NaN        NaN        NaN
# 2012-10-01 13:00:00    18.720000  18.380000  20.260000  23.450000
# 2012-10-01 14:00:00    18.718186  18.383501  20.253141  23.458509
# 2012-10-01 15:00:00    18.712845  18.393355  20.242177  23.481487
# 2012-10-01 16:00:00    18.707503  18.403209  20.231213  23.504466
#
#                      Albuquerque     Denver  ...  Philadelphia   New York  \
# datetime                                     ...
# 2012-10-01 12:00:00          NaN        NaN  ...           NaN        NaN
# 2012-10-01 13:00:00    11.970000  11.460000  ...     12.480000  15.070000
# 2012-10-01 14:00:00    12.004558  11.457306  ...     12.513208  15.097676
# 2012-10-01 15:00:00    12.083952  11.449918  ...     12.606824  15.176940
# 2012-10-01 16:00:00    12.163345  11.442530  ...     12.700441  15.256203
#
#                       Montreal     Boston  Beersheba  Tel Aviv District  \
# datetime
# 2012-10-01 12:00:00        NaN        NaN        NaN                NaN
# 2012-10-01 13:00:00  12.680000  14.020000  34.440000          32.320000
# 2012-10-01 14:00:00  12.684650  14.036092  34.440000          31.160000
# 2012-10-01 15:00:00  12.697789  14.081672  34.241513          31.131841
# 2012-10-01 16:00:00  12.710929  14.127251  33.995200          31.088015
#
#                          Eilat  Haifa  Nahariyya  Jerusalem
# datetime
# 2012-10-01 12:00:00  35.950000    NaN        NaN        NaN
# 2012-10-01 13:00:00  37.430000  31.25      31.25      30.35
# 2012-10-01 14:00:00  37.345769  31.25      31.25      30.35
# 2012-10-01 15:00:00  37.261539  31.25      31.25      30.35
# 2012-10-01 16:00:00  37.177308  31.25      31.25      30.35
#
# [5 rows x 36 columns]

# %% [markdown]
# 4. Write a function that efficiently fills in missing values in every column, excluding trailing NANs. That is: if there's temperature data on either side of a timestamp, it should interpolate through it. But if data stopped being collected, your function should leave nans at the end.

# %%
# I will use the .interpolate() function to full NANs in my data

temperature_df_Celsius_patched = temperature_df_Celsius.interpolate(limit_area='inside')

#Here, I am checking to see if the numbers have changed as an indication
# that my .interpolate() worked.

print(temperature_df_Celsius_patched.isna().sum().sum())
print(temperature_df_Celsius.isna().sum().sum())


print(temperature_df_Celsius_patched['Montreal'].isna())
print(temperature_df_Celsius['Montreal'].isna())

#Just checking: 
temperature_df_Celsius['Montreal']
# Out:
# 7955
# 8030
# datetime
# 2012-10-01 12:00:00     True
# 2012-10-01 13:00:00    False
# 2012-10-01 14:00:00    False
# 2012-10-01 15:00:00    False
# 2012-10-01 16:00:00    False
#                        ...
# 2017-11-29 20:00:00    False
# 2017-11-29 21:00:00    False
# 2017-11-29 22:00:00    False
# 2017-11-29 23:00:00    False
# 2017-11-30 00:00:00    False
# Name: Montreal, Length: 45253, dtype: bool
# datetime
# 2012-10-01 12:00:00     True
# 2012-10-01 13:00:00    False
# 2012-10-01 14:00:00    False
# 2012-10-01 15:00:00    False
# 2012-10-01 16:00:00    False
#                        ...
# 2017-11-29 20:00:00    False
# 2017-11-29 21:00:00    False
# 2017-11-29 22:00:00    False
# 2017-11-29 23:00:00    False
# 2017-11-30 00:00:00    False
# Name: Montreal, Length: 45253, dtype: bool
# datetime
# 2012-10-01 12:00:00          NaN
# 2012-10-01 13:00:00    12.680000
# 2012-10-01 14:00:00    12.684650
# 2012-10-01 15:00:00    12.697789
# 2012-10-01 16:00:00    12.710929
#                          ...
# 2017-11-29 20:00:00     1.980000
# 2017-11-29 21:00:00     0.980000
# 2017-11-29 22:00:00     0.330000
# 2017-11-29 23:00:00    -0.670000
# 2017-11-30 00:00:00    -1.350000
# Name: Montreal, Length: 45253, dtype: float64

# %% [markdown]
# 5. Find all cities A and B where city A is warmer than city B in the summer, but also colder than city B in the winter, on average.

# %%
# temperature_df_Celsius_patched = temperature_df_Celsius_patched.asfreq('1H')
# quarterly_data = temperature_df_Celsius_patched.asfreq('Q')
# quarterly_data.head()

# %%
# separating months from the datetime index
#temperature_df_Celsius_patched['datetime']= pd.to_datetime(temperature_df_Celsius_patched['datetime'], errors='coerce')
temperature_df_Celsius_patched['month']= pd.DatetimeIndex(temperature_df_Celsius_patched.index).month
temperature_df_Celsius_patched.head()
x=temperature_df_Celsius_patched
summer_months= [5,6,7,8,9]
winter_months=[10,11,12,1,2,3,4]
x[x.month.isin(summer_months)]
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2013-05-01 00:00:00      11.40     13.88          27.29    12.83        21.11
# 2013-05-01 01:00:00      10.96     13.43          27.10    11.98        20.67
# 2013-05-01 02:00:00      10.29     11.11          25.24    10.13        19.13
# 2013-05-01 03:00:00       9.47      8.93          23.17     8.44        17.28
# 2013-05-01 04:00:00       8.43      7.75          19.86     7.40        16.29
# ...                        ...       ...            ...      ...          ...
# 2017-09-30 19:00:00      13.77     14.86          19.09    14.99        23.36
# 2017-09-30 20:00:00      13.80     16.50          21.08    15.99        24.95
# 2017-09-30 21:00:00      13.41     16.37          22.46    15.89        25.89
# 2017-09-30 22:00:00      13.00     16.30          24.25    16.10        26.29
# 2017-09-30 23:00:00      13.59     16.63          24.66    14.89        26.07
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2013-05-01 00:00:00      19.43      36.07    37.77        25.93   24.19  ...
# 2013-05-01 01:00:00      17.97      35.69    37.28        24.40   23.32  ...
# 2013-05-01 02:00:00      16.94      34.74    35.74        22.26   22.14  ...
# 2013-05-01 03:00:00      15.14      32.39    33.77        19.42   20.60  ...
# 2013-05-01 04:00:00      14.50      31.74    32.26        18.47   18.77  ...
# ...                        ...        ...      ...          ...     ...  ...
# 2017-09-30 19:00:00      23.46      31.20    31.13        19.02   19.28  ...
# 2017-09-30 20:00:00      24.16      32.20    32.70        20.76   19.64  ...
# 2017-09-30 21:00:00      24.70      31.99    34.00        20.77   20.57  ...
# 2017-09-30 22:00:00      24.47      32.32    35.22        20.45   20.23  ...
# 2017-09-30 23:00:00      24.44      32.49    35.30        19.99   19.32  ...
#
#                      New York  Montreal  Boston  Beersheba  Tel Aviv District  \
# datetime
# 2013-05-01 00:00:00     12.60    16.590   15.26     19.350              21.00
# 2013-05-01 01:00:00     12.04    16.070   13.69     19.350              21.00
# 2013-05-01 02:00:00     12.03    14.640   12.55     19.350              21.72
# 2013-05-01 03:00:00     12.01    13.880   11.45     27.250              21.72
# 2013-05-01 04:00:00     11.81    12.807   10.97     27.250              21.00
# ...                       ...       ...     ...        ...                ...
# 2017-09-30 19:00:00     17.00    13.670   12.63     19.383              25.56
# 2017-09-30 20:00:00     16.36    15.000   12.23     15.161              25.56
# 2017-09-30 21:00:00     15.60    14.670   12.39     15.161              25.11
# 2017-09-30 22:00:00     15.00    14.670   12.17     15.161              23.67
# 2017-09-30 23:00:00     13.36    13.650   11.42     13.193              23.56
#
#                       Eilat   Haifa  Nahariyya  Jerusalem  month
# datetime
# 2013-05-01 00:00:00  23.950  21.850     21.850      19.15      5
# 2013-05-01 01:00:00  21.000  21.850     21.850      19.15      5
# 2013-05-01 02:00:00  23.800  21.850     21.850      19.15      5
# 2013-05-01 03:00:00  23.430  24.950     24.950      28.25      5
# 2013-05-01 04:00:00  19.000  24.950     24.950      28.25      5
# ...                     ...     ...        ...        ...    ...
# 2017-09-30 19:00:00  29.510  25.933     25.933      25.61      9
# 2017-09-30 20:00:00  29.020  25.861     25.861      25.61      9
# 2017-09-30 21:00:00  28.020  25.861     25.861      25.22      9
# 2017-09-30 22:00:00  27.020  25.861     25.861      23.83      9
# 2017-09-30 23:00:00  20.793  25.668     25.668      23.61      9
#
# [18360 rows x 37 columns]

# %%
#Calculated averages for cities during summer months.
avg_summer = x[x.month.isin(summer_months)].iloc[:,0:36].mean().round(2)
#avg_summer
#Calculated averages for cities during winter months.
avg_winter =x[x.month.isin(winter_months)].iloc[:,0:36].mean().round(2)
print(avg_summer, avg_winter)
# Out:
# Vancouver            16.67
# Portland             17.98
# San Francisco        18.20
# Seattle              16.84
# Los Angeles          21.59
# San Diego            20.39
# Las Vegas            28.69
# Phoenix              30.65
# Albuquerque          20.54
# Denver               18.29
# San Antonio          26.89
# Dallas               27.02
# Houston              27.06
# Kansas City          22.81
# Minneapolis          19.08
# Saint Louis          22.92
# Chicago              19.81
# Nashville            23.50
# Indianapolis         21.17
# Atlanta              23.79
# Detroit              19.70
# Jacksonville         26.34
# Charlotte            23.35
# Miami                27.69
# Pittsburgh           19.75
# Toronto              18.37
# Philadelphia         21.17
# New York             21.22
# Montreal             18.12
# Boston               19.26
# Beersheba            23.89
# Tel Aviv District    26.57
# Eilat                30.15
# Haifa                27.11
# Nahariyya            25.48
# Jerusalem            25.48
# dtype: float64 Vancouver             6.52
# Portland              7.65
# San Francisco        12.76
# Seattle               7.45
# Los Angeles          15.04
# San Diego            14.79
# Las Vegas            12.85
# Phoenix              16.67
# Albuquerque           6.95
# Denver                3.82
# San Antonio          16.36
# Dallas               13.90
# Houston              16.95
# Kansas City           7.13
# Minneapolis          -0.33
# Saint Louis           7.11
# Chicago               3.64
# Nashville             9.90
# Indianapolis          5.11
# Atlanta              11.73
# Detroit               3.08
# Jacksonville         17.66
# Charlotte            10.56
# Miami                23.16
# Pittsburgh            4.87
# Toronto               2.25
# Philadelphia          6.12
# New York              5.94
# Montreal             -0.27
# Boston                4.74
# Beersheba            14.49
# Tel Aviv District    17.70
# Eilat                18.56
# Haifa                18.61
# Nahariyya            17.75
# Jerusalem            16.20
# dtype: float64

# %%
#created dataframe with the average values and cities
average_df=pd.DataFrame(avg_summer)
average_df.columns=['summer_avg']
average_df['winter_avg']=avg_winter
average_df=average_df.reset_index()
average_df.columns=['city','summer_avg','winter_avg']
average_df
# Out:
#                  city  summer_avg  winter_avg
# 0           Vancouver       16.67        6.52
# 1            Portland       17.98        7.65
# 2       San Francisco       18.20       12.76
# 3             Seattle       16.84        7.45
# 4         Los Angeles       21.59       15.04
# 5           San Diego       20.39       14.79
# 6           Las Vegas       28.69       12.85
# 7             Phoenix       30.65       16.67
# 8         Albuquerque       20.54        6.95
# 9              Denver       18.29        3.82
# 10        San Antonio       26.89       16.36
# 11             Dallas       27.02       13.90
# 12            Houston       27.06       16.95
# 13        Kansas City       22.81        7.13
# 14        Minneapolis       19.08       -0.33
# 15        Saint Louis       22.92        7.11
# 16            Chicago       19.81        3.64
# 17          Nashville       23.50        9.90
# 18       Indianapolis       21.17        5.11
# 19            Atlanta       23.79       11.73
# 20            Detroit       19.70        3.08
# 21       Jacksonville       26.34       17.66
# 22          Charlotte       23.35       10.56
# 23              Miami       27.69       23.16
# 24         Pittsburgh       19.75        4.87
# 25            Toronto       18.37        2.25
# 26       Philadelphia       21.17        6.12
# 27           New York       21.22        5.94
# 28           Montreal       18.12       -0.27
# 29             Boston       19.26        4.74
# 30          Beersheba       23.89       14.49
# 31  Tel Aviv District       26.57       17.70
# 32              Eilat       30.15       18.56
# 33              Haifa       27.11       18.61
# 34          Nahariyya       25.48       17.75
# 35          Jerusalem       25.48       16.20

# %%
#Iterated inside the average df and compared which the city temp is greater in summer and for the same city temp 
#is less than in winter and print the results.
cityA=[]
cityB=[]

for i in range(len(average_df['city'])):
    city=average_df.iloc[i,0]
    summer_temp=average_df.iloc[i,1]
    winter_temp=average_df.iloc[i,2]
    for j in range(len(average_df['city'])):
        if city!=average_df.iloc[j,0]:
            if (summer_temp>average_df.iloc[j,1]) & (winter_temp<average_df.iloc[j,2]):
                cityA.append(city)
                cityB.append(average_df.iloc[j,0])
                print(city," temperature ",summer_temp," is hotter than ",average_df.iloc[j,0],average_df.iloc[j,1])
                print(city," temperature ",winter_temp," is colder than ",average_df.iloc[j,0],average_df.iloc[j,2])
# Out:
# Las Vegas  temperature  28.69  is hotter than  Los Angeles 21.59
# Las Vegas  temperature  12.85  is colder than  Los Angeles 15.04
# Las Vegas  temperature  28.69  is hotter than  San Diego 20.39
# Las Vegas  temperature  12.85  is colder than  San Diego 14.79
# Las Vegas  temperature  28.69  is hotter than  San Antonio 26.89
# Las Vegas  temperature  12.85  is colder than  San Antonio 16.36
# Las Vegas  temperature  28.69  is hotter than  Dallas 27.02
# Las Vegas  temperature  12.85  is colder than  Dallas 13.9
# Las Vegas  temperature  28.69  is hotter than  Houston 27.06
# Las Vegas  temperature  12.85  is colder than  Houston 16.95
# Las Vegas  temperature  28.69  is hotter than  Jacksonville 26.34
# Las Vegas  temperature  12.85  is colder than  Jacksonville 17.66
# Las Vegas  temperature  28.69  is hotter than  Miami 27.69
# Las Vegas  temperature  12.85  is colder than  Miami 23.16
# Las Vegas  temperature  28.69  is hotter than  Beersheba 23.89
# Las Vegas  temperature  12.85  is colder than  Beersheba 14.49
# Las Vegas  temperature  28.69  is hotter than  Tel Aviv District 26.57
# Las Vegas  temperature  12.85  is colder than  Tel Aviv District 17.7
# Las Vegas  temperature  28.69  is hotter than  Haifa 27.11
# Las Vegas  temperature  12.85  is colder than  Haifa 18.61
# Las Vegas  temperature  28.69  is hotter than  Nahariyya 25.48
# Las Vegas  temperature  12.85  is colder than  Nahariyya 17.75
# Las Vegas  temperature  28.69  is hotter than  Jerusalem 25.48
# Las Vegas  temperature  12.85  is colder than  Jerusalem 16.2
# Phoenix  temperature  30.65  is hotter than  Houston 27.06
# Phoenix  temperature  16.67  is colder than  Houston 16.95
# Phoenix  temperature  30.65  is hotter than  Jacksonville 26.34
# Phoenix  temperature  16.67  is colder than  Jacksonville 17.66
# Phoenix  temperature  30.65  is hotter than  Miami 27.69
# Phoenix  temperature  16.67  is colder than  Miami 23.16
# Phoenix  temperature  30.65  is hotter than  Tel Aviv District 26.57
# Phoenix  temperature  16.67  is colder than  Tel Aviv District 17.7
# Phoenix  temperature  30.65  is hotter than  Eilat 30.15
# Phoenix  temperature  16.67  is colder than  Eilat 18.56
# Phoenix  temperature  30.65  is hotter than  Haifa 27.11
# Phoenix  temperature  16.67  is colder than  Haifa 18.61
# Phoenix  temperature  30.65  is hotter than  Nahariyya 25.48
# Phoenix  temperature  16.67  is colder than  Nahariyya 17.75
# Albuquerque  temperature  20.54  is hotter than  Portland 17.98
# Albuquerque  temperature  6.95  is colder than  Portland 7.65
# Albuquerque  temperature  20.54  is hotter than  San Francisco 18.2
# Albuquerque  temperature  6.95  is colder than  San Francisco 12.76
# Albuquerque  temperature  20.54  is hotter than  Seattle 16.84
# Albuquerque  temperature  6.95  is colder than  Seattle 7.45
# Albuquerque  temperature  20.54  is hotter than  San Diego 20.39
# Albuquerque  temperature  6.95  is colder than  San Diego 14.79
# Denver  temperature  18.29  is hotter than  Vancouver 16.67
# Denver  temperature  3.82  is colder than  Vancouver 6.52
# Denver  temperature  18.29  is hotter than  Portland 17.98
# Denver  temperature  3.82  is colder than  Portland 7.65
# Denver  temperature  18.29  is hotter than  San Francisco 18.2
# Denver  temperature  3.82  is colder than  San Francisco 12.76
# Denver  temperature  18.29  is hotter than  Seattle 16.84
# Denver  temperature  3.82  is colder than  Seattle 7.45
# San Antonio  temperature  26.89  is hotter than  Jacksonville 26.34
# San Antonio  temperature  16.36  is colder than  Jacksonville 17.66
# San Antonio  temperature  26.89  is hotter than  Tel Aviv District 26.57
# San Antonio  temperature  16.36  is colder than  Tel Aviv District 17.7
# San Antonio  temperature  26.89  is hotter than  Nahariyya 25.48
# San Antonio  temperature  16.36  is colder than  Nahariyya 17.75
# Dallas  temperature  27.02  is hotter than  Los Angeles 21.59
# Dallas  temperature  13.9  is colder than  Los Angeles 15.04
# Dallas  temperature  27.02  is hotter than  San Diego 20.39
# Dallas  temperature  13.9  is colder than  San Diego 14.79
# Dallas  temperature  27.02  is hotter than  San Antonio 26.89
# Dallas  temperature  13.9  is colder than  San Antonio 16.36
# Dallas  temperature  27.02  is hotter than  Jacksonville 26.34
# Dallas  temperature  13.9  is colder than  Jacksonville 17.66
# Dallas  temperature  27.02  is hotter than  Beersheba 23.89
# Dallas  temperature  13.9  is colder than  Beersheba 14.49
# Dallas  temperature  27.02  is hotter than  Tel Aviv District 26.57
# Dallas  temperature  13.9  is colder than  Tel Aviv District 17.7
# Dallas  temperature  27.02  is hotter than  Nahariyya 25.48
# Dallas  temperature  13.9  is colder than  Nahariyya 17.75
# Dallas  temperature  27.02  is hotter than  Jerusalem 25.48
# Dallas  temperature  13.9  is colder than  Jerusalem 16.2
# Houston  temperature  27.06  is hotter than  Jacksonville 26.34
# Houston  temperature  16.95  is colder than  Jacksonville 17.66
# Houston  temperature  27.06  is hotter than  Tel Aviv District 26.57
# Houston  temperature  16.95  is colder than  Tel Aviv District 17.7
# Houston  temperature  27.06  is hotter than  Nahariyya 25.48
# Houston  temperature  16.95  is colder than  Nahariyya 17.75
# Kansas City  temperature  22.81  is hotter than  Portland 17.98
# Kansas City  temperature  7.13  is colder than  Portland 7.65
# Kansas City  temperature  22.81  is hotter than  San Francisco 18.2
# Kansas City  temperature  7.13  is colder than  San Francisco 12.76
# Kansas City  temperature  22.81  is hotter than  Seattle 16.84
# Kansas City  temperature  7.13  is colder than  Seattle 7.45
# Kansas City  temperature  22.81  is hotter than  Los Angeles 21.59
# Kansas City  temperature  7.13  is colder than  Los Angeles 15.04
# Kansas City  temperature  22.81  is hotter than  San Diego 20.39
# Kansas City  temperature  7.13  is colder than  San Diego 14.79
# Minneapolis  temperature  19.08  is hotter than  Vancouver 16.67
# Minneapolis  temperature  -0.33  is colder than  Vancouver 6.52
# Minneapolis  temperature  19.08  is hotter than  Portland 17.98
# Minneapolis  temperature  -0.33  is colder than  Portland 7.65
# Minneapolis  temperature  19.08  is hotter than  San Francisco 18.2
# Minneapolis  temperature  -0.33  is colder than  San Francisco 12.76
# Minneapolis  temperature  19.08  is hotter than  Seattle 16.84
# Minneapolis  temperature  -0.33  is colder than  Seattle 7.45
# Minneapolis  temperature  19.08  is hotter than  Denver 18.29
# Minneapolis  temperature  -0.33  is colder than  Denver 3.82
# Minneapolis  temperature  19.08  is hotter than  Toronto 18.37
# Minneapolis  temperature  -0.33  is colder than  Toronto 2.25
# Minneapolis  temperature  19.08  is hotter than  Montreal 18.12
# Minneapolis  temperature  -0.33  is colder than  Montreal -0.27
# Saint Louis  temperature  22.92  is hotter than  Portland 17.98
# Saint Louis  temperature  7.11  is colder than  Portland 7.65
# Saint Louis  temperature  22.92  is hotter than  San Francisco 18.2
# Saint Louis  temperature  7.11  is colder than  San Francisco 12.76
# Saint Louis  temperature  22.92  is hotter than  Seattle 16.84
# Saint Louis  temperature  7.11  is colder than  Seattle 7.45
# Saint Louis  temperature  22.92  is hotter than  Los Angeles 21.59
# Saint Louis  temperature  7.11  is colder than  Los Angeles 15.04
# Saint Louis  temperature  22.92  is hotter than  San Diego 20.39
# Saint Louis  temperature  7.11  is colder than  San Diego 14.79
# Saint Louis  temperature  22.92  is hotter than  Kansas City 22.81
# Saint Louis  temperature  7.11  is colder than  Kansas City 7.13
# Chicago  temperature  19.81  is hotter than  Vancouver 16.67
# Chicago  temperature  3.64  is colder than  Vancouver 6.52
# Chicago  temperature  19.81  is hotter than  Portland 17.98
# Chicago  temperature  3.64  is colder than  Portland 7.65
# Chicago  temperature  19.81  is hotter than  San Francisco 18.2
# Chicago  temperature  3.64  is colder than  San Francisco 12.76
# Chicago  temperature  19.81  is hotter than  Seattle 16.84
# Chicago  temperature  3.64  is colder than  Seattle 7.45
# Chicago  temperature  19.81  is hotter than  Denver 18.29
# Chicago  temperature  3.64  is colder than  Denver 3.82
# Chicago  temperature  19.81  is hotter than  Pittsburgh 19.75
# Chicago  temperature  3.64  is colder than  Pittsburgh 4.87
# Chicago  temperature  19.81  is hotter than  Boston 19.26
# Chicago  temperature  3.64  is colder than  Boston 4.74
# Nashville  temperature  23.5  is hotter than  San Francisco 18.2
# Nashville  temperature  9.9  is colder than  San Francisco 12.76
# Nashville  temperature  23.5  is hotter than  Los Angeles 21.59
# Nashville  temperature  9.9  is colder than  Los Angeles 15.04
# Nashville  temperature  23.5  is hotter than  San Diego 20.39
# Nashville  temperature  9.9  is colder than  San Diego 14.79
# Nashville  temperature  23.5  is hotter than  Charlotte 23.35
# Nashville  temperature  9.9  is colder than  Charlotte 10.56
# Indianapolis  temperature  21.17  is hotter than  Vancouver 16.67
# Indianapolis  temperature  5.11  is colder than  Vancouver 6.52
# Indianapolis  temperature  21.17  is hotter than  Portland 17.98
# Indianapolis  temperature  5.11  is colder than  Portland 7.65
# Indianapolis  temperature  21.17  is hotter than  San Francisco 18.2
# Indianapolis  temperature  5.11  is colder than  San Francisco 12.76
# Indianapolis  temperature  21.17  is hotter than  Seattle 16.84
# Indianapolis  temperature  5.11  is colder than  Seattle 7.45
# Indianapolis  temperature  21.17  is hotter than  San Diego 20.39
# Indianapolis  temperature  5.11  is colder than  San Diego 14.79
# Indianapolis  temperature  21.17  is hotter than  Albuquerque 20.54
# Indianapolis  temperature  5.11  is colder than  Albuquerque 6.95
# Atlanta  temperature  23.79  is hotter than  San Francisco 18.2
# Atlanta  temperature  11.73  is colder than  San Francisco 12.76
# Atlanta  temperature  23.79  is hotter than  Los Angeles 21.59
# Atlanta  temperature  11.73  is colder than  Los Angeles 15.04
# Atlanta  temperature  23.79  is hotter than  San Diego 20.39
# Atlanta  temperature  11.73  is colder than  San Diego 14.79
# Detroit  temperature  19.7  is hotter than  Vancouver 16.67
# Detroit  temperature  3.08  is colder than  Vancouver 6.52
# Detroit  temperature  19.7  is hotter than  Portland 17.98
# Detroit  temperature  3.08  is colder than  Portland 7.65
# Detroit  temperature  19.7  is hotter than  San Francisco 18.2
# Detroit  temperature  3.08  is colder than  San Francisco 12.76
# Detroit  temperature  19.7  is hotter than  Seattle 16.84
# Detroit  temperature  3.08  is colder than  Seattle 7.45
# Detroit  temperature  19.7  is hotter than  Denver 18.29
# Detroit  temperature  3.08  is colder than  Denver 3.82
# Detroit  temperature  19.7  is hotter than  Boston 19.26
# Detroit  temperature  3.08  is colder than  Boston 4.74
# Jacksonville  temperature  26.34  is hotter than  Nahariyya 25.48
# Jacksonville  temperature  17.66  is colder than  Nahariyya 17.75
# Charlotte  temperature  23.35  is hotter than  San Francisco 18.2
# Charlotte  temperature  10.56  is colder than  San Francisco 12.76
# Charlotte  temperature  23.35  is hotter than  Los Angeles 21.59
# Charlotte  temperature  10.56  is colder than  Los Angeles 15.04
# Charlotte  temperature  23.35  is hotter than  San Diego 20.39
# Charlotte  temperature  10.56  is colder than  San Diego 14.79
# Pittsburgh  temperature  19.75  is hotter than  Vancouver 16.67
# Pittsburgh  temperature  4.87  is colder than  Vancouver 6.52
# Pittsburgh  temperature  19.75  is hotter than  Portland 17.98
# Pittsburgh  temperature  4.87  is colder than  Portland 7.65
# Pittsburgh  temperature  19.75  is hotter than  San Francisco 18.2
# Pittsburgh  temperature  4.87  is colder than  San Francisco 12.76
# Pittsburgh  temperature  19.75  is hotter than  Seattle 16.84
# Pittsburgh  temperature  4.87  is colder than  Seattle 7.45
# Toronto  temperature  18.37  is hotter than  Vancouver 16.67
# Toronto  temperature  2.25  is colder than  Vancouver 6.52
# Toronto  temperature  18.37  is hotter than  Portland 17.98
# Toronto  temperature  2.25  is colder than  Portland 7.65
# Toronto  temperature  18.37  is hotter than  San Francisco 18.2
# Toronto  temperature  2.25  is colder than  San Francisco 12.76
# Toronto  temperature  18.37  is hotter than  Seattle 16.84
# Toronto  temperature  2.25  is colder than  Seattle 7.45
# Toronto  temperature  18.37  is hotter than  Denver 18.29
# Toronto  temperature  2.25  is colder than  Denver 3.82
# Philadelphia  temperature  21.17  is hotter than  Vancouver 16.67
# Philadelphia  temperature  6.12  is colder than  Vancouver 6.52
# Philadelphia  temperature  21.17  is hotter than  Portland 17.98
# Philadelphia  temperature  6.12  is colder than  Portland 7.65
# Philadelphia  temperature  21.17  is hotter than  San Francisco 18.2
# Philadelphia  temperature  6.12  is colder than  San Francisco 12.76
# Philadelphia  temperature  21.17  is hotter than  Seattle 16.84
# Philadelphia  temperature  6.12  is colder than  Seattle 7.45
# Philadelphia  temperature  21.17  is hotter than  San Diego 20.39
# Philadelphia  temperature  6.12  is colder than  San Diego 14.79
# Philadelphia  temperature  21.17  is hotter than  Albuquerque 20.54
# Philadelphia  temperature  6.12  is colder than  Albuquerque 6.95
# New York  temperature  21.22  is hotter than  Vancouver 16.67
# New York  temperature  5.94  is colder than  Vancouver 6.52
# New York  temperature  21.22  is hotter than  Portland 17.98
# New York  temperature  5.94  is colder than  Portland 7.65
# New York  temperature  21.22  is hotter than  San Francisco 18.2
# New York  temperature  5.94  is colder than  San Francisco 12.76
# New York  temperature  21.22  is hotter than  Seattle 16.84
# New York  temperature  5.94  is colder than  Seattle 7.45
# New York  temperature  21.22  is hotter than  San Diego 20.39
# New York  temperature  5.94  is colder than  San Diego 14.79
# New York  temperature  21.22  is hotter than  Albuquerque 20.54
# New York  temperature  5.94  is colder than  Albuquerque 6.95
# New York  temperature  21.22  is hotter than  Philadelphia 21.17
# New York  temperature  5.94  is colder than  Philadelphia 6.12
# Montreal  temperature  18.12  is hotter than  Vancouver 16.67
# Montreal  temperature  -0.27  is colder than  Vancouver 6.52
# Montreal  temperature  18.12  is hotter than  Portland 17.98
# Montreal  temperature  -0.27  is colder than  Portland 7.65
# Montreal  temperature  18.12  is hotter than  Seattle 16.84
# Montreal  temperature  -0.27  is colder than  Seattle 7.45
# Boston  temperature  19.26  is hotter than  Vancouver 16.67
# Boston  temperature  4.74  is colder than  Vancouver 6.52
# Boston  temperature  19.26  is hotter than  Portland 17.98
# Boston  temperature  4.74  is colder than  Portland 7.65
# Boston  temperature  19.26  is hotter than  San Francisco 18.2
# Boston  temperature  4.74  is colder than  San Francisco 12.76
# Boston  temperature  19.26  is hotter than  Seattle 16.84
# Boston  temperature  4.74  is colder than  Seattle 7.45
# Beersheba  temperature  23.89  is hotter than  Los Angeles 21.59
# Beersheba  temperature  14.49  is colder than  Los Angeles 15.04
# Beersheba  temperature  23.89  is hotter than  San Diego 20.39
# Beersheba  temperature  14.49  is colder than  San Diego 14.79
# Tel Aviv District  temperature  26.57  is hotter than  Nahariyya 25.48
# Tel Aviv District  temperature  17.7  is colder than  Nahariyya 17.75
# Eilat  temperature  30.15  is hotter than  Miami 27.69
# Eilat  temperature  18.56  is colder than  Miami 23.16
# Eilat  temperature  30.15  is hotter than  Haifa 27.11
# Eilat  temperature  18.56  is colder than  Haifa 18.61

# %% [markdown]
# 6. For two of the cities you found in question 5 (there are many possible answers), clean up the data via rolling averages and plot a clear visual. Explain how rolling average differs from moving average (MA) model.

# %%
temperature_df_Celsius_patched[["Chicago","Albuquerque"]].rolling('30D').mean().plot(title="Temperature comparison: Chicago vs. Albuquerque")
plt.xlabel("Year")
plt.ylabel("Temperature (Celsius)")
plt.show()

# %% [markdown]
# Rolling average takes average of the data points in a widow. In the above case a widow of 30 calendar days were selected to calculate average temperature.
#
# Moving average model is used for time series analysis for future prediction. It is used when the output data is linearly dependendt on the past and present values. Because of this MA model assumes equal weights for all data points unlike the rolling average.

# %% [markdown]
# 7. Perform SARIMA on five cities, iterating through the cities programmatically. Explain your results. Graph the predicted values 30 days out.

# %%
# Resampling the data for from hourly to daily
resampled_df = temperature_df_Celsius_patched.resample('W').mean()

# Choosing my five cities for the SARIMA df:
my_cities = resampled_df.loc[:,['Chicago', 'Albuquerque', 'Miami', 'Minneapolis', 'Denver']]
my_cities.head(3)
# Out:
#               Chicago  Albuquerque      Miami  Minneapolis     Denver
# datetime
# 2012-10-07  13.345701    17.853271  27.537268    11.189519   9.831460
# 2012-10-14   9.236339    13.178452  26.637589     6.788125   9.010298
# 2012-10-21  11.990923    14.418958  26.547113     9.772887  12.702232

# %%
# Suppress ugly warnings for improper values 
import warnings
warnings.filterwarnings('ignore')

#Modeling the data! 
my_cities_stationary = my_cities.copy(deep=False)

for i in my_cities:
    
    #converting to a stationary series by taking seasonal and nonseasonal difference
    my_cities_stationary["diff_"+i]=my_cities_stationary[i].diff().diff(7).dropna()
    my_cities_stationary=my_cities_stationary.dropna()
    
    #plotting my acf, pacf
    fig, ax = plt.subplots(1,2, figsize=(20,5))
    plot_acf(my_cities_stationary[["diff_"+i]],zero=False,lags=52, ax=ax[0],missing='drop',title=i + " ACF");
    plot_pacf(my_cities_stationary[["diff_"+i]],lags=52, ax=ax[1],method='ywm',title=i + " PACF");

# %%
model = pd.Series()
results = pd.Series()
for i in my_cities:
    model[i] = SARIMAX(my_cities_stationary[i],order=(0,1,0), seasonal_order=(2,1,0,52))
    results[i] = model[i].fit(low_memory=True)
    print(results[i].summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                            Chicago   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -512.734
# Date:                            Sat, 11 Dec 2021   AIC                           1031.468
# Time:                                    16:02:02   BIC                           1040.910
# Sample:                                07-14-2013   HQIC                          1035.299
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.6811      0.101     -6.757      0.000      -0.879      -0.484
# ar.S.L104     -0.2609      0.117     -2.236      0.025      -0.490      -0.032
# sigma2        19.6332      2.323      8.453      0.000      15.081      24.185
# ===================================================================================
# Ljung-Box (L1) (Q):                  13.80   Jarque-Bera (JB):                 2.62
# Prob(Q):                              0.00   Prob(JB):                         0.27
# Heteroskedasticity (H):               1.00   Skew:                            -0.10
# Prob(H) (two-sided):                  0.99   Kurtosis:                         3.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                        Albuquerque   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -453.114
# Date:                            Sat, 11 Dec 2021   AIC                            912.228
# Time:                                    16:02:16   BIC                            921.670
# Sample:                                07-14-2013   HQIC                           916.059
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.6846      0.098     -7.022      0.000      -0.876      -0.494
# ar.S.L104     -0.5316      0.083     -6.411      0.000      -0.694      -0.369
# sigma2         8.6947      1.153      7.544      0.000       6.436      10.954
# ===================================================================================
# Ljung-Box (L1) (Q):                  26.93   Jarque-Bera (JB):                 0.69
# Prob(Q):                              0.00   Prob(JB):                         0.71
# Heteroskedasticity (H):               1.15   Skew:                             0.15
# Prob(H) (two-sided):                  0.61   Kurtosis:                         2.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Miami   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -362.224
# Date:                            Sat, 11 Dec 2021   AIC                            730.449
# Time:                                    16:02:29   BIC                            739.891
# Sample:                                07-14-2013   HQIC                           734.280
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.8873      0.099     -8.918      0.000      -1.082      -0.692
# ar.S.L104     -0.2922      0.116     -2.516      0.012      -0.520      -0.065
# sigma2         3.0871      0.378      8.174      0.000       2.347       3.827
# ===================================================================================
# Ljung-Box (L1) (Q):                  17.49   Jarque-Bera (JB):               103.80
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.27   Skew:                             0.07
# Prob(H) (two-sided):                  0.37   Kurtosis:                         6.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                        Minneapolis   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -542.312
# Date:                            Sat, 11 Dec 2021   AIC                           1090.624
# Time:                                    16:02:44   BIC                           1100.067
# Sample:                                07-14-2013   HQIC                          1094.455
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.6089      0.101     -6.021      0.000      -0.807      -0.411
# ar.S.L104     -0.2820      0.118     -2.391      0.017      -0.513      -0.051
# sigma2        28.2390      3.354      8.420      0.000      21.666      34.812
# ===================================================================================
# Ljung-Box (L1) (Q):                  11.08   Jarque-Bera (JB):                 2.05
# Prob(Q):                              0.00   Prob(JB):                         0.36
# Heteroskedasticity (H):               0.80   Skew:                             0.02
# Prob(H) (two-sided):                  0.40   Kurtosis:                         3.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                             Denver   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -503.524
# Date:                            Sat, 11 Dec 2021   AIC                           1013.048
# Time:                                    16:02:59   BIC                           1022.491
# Sample:                                07-14-2013   HQIC                          1016.880
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.8056      0.088     -9.198      0.000      -0.977      -0.634
# ar.S.L104     -0.5278      0.087     -6.074      0.000      -0.698      -0.357
# sigma2        15.1976      2.019      7.528      0.000      11.241      19.155
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.90   Jarque-Bera (JB):                 5.71
# Prob(Q):                              0.00   Prob(JB):                         0.06
# Heteroskedasticity (H):               1.18   Skew:                            -0.18
# Prob(H) (two-sided):                  0.54   Kurtosis:                         3.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# When I look at my summary, I can see that all of my P values are within acceptable range. My stationarity is acceptable after differencing the data, and mh correlation coefficients are nice and tight. Looks like this data shaped up well.

# %%
for i in my_cities:
    results[i].forecast(steps=6).plot(legend=True,title="30 Day Forecast".format(city=i), xlabel="Date", ylabel="Temperature(Celsius)")
plt.legend(['Chicago', 'Albuquerque', 'Miami', 'Minneapolis', 'Denver'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# 8. Explain what you see when you perform results.summary() on the cities in question 7.

# %%
#Print a summary for each city 
for i in my_cities:
    print("\033[1m Summary for ",i,": \n \033[0m", results[i].summary())
# Out:
#  Summary for  Chicago :
#                                        SARIMAX Results
# ==========================================================================================
# Dep. Variable:                            Chicago   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -512.734
# Date:                            Sat, 11 Dec 2021   AIC                           1031.468
# Time:                                    15:53:02   BIC                           1040.910
# Sample:                                07-14-2013   HQIC                          1035.299
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.6811      0.101     -6.757      0.000      -0.879      -0.484
# ar.S.L104     -0.2609      0.117     -2.236      0.025      -0.490      -0.032
# sigma2        19.6332      2.323      8.453      0.000      15.081      24.185
# ===================================================================================
# Ljung-Box (L1) (Q):                  13.80   Jarque-Bera (JB):                 2.62
# Prob(Q):                              0.00   Prob(JB):                         0.27
# Heteroskedasticity (H):               1.00   Skew:                            -0.10
# Prob(H) (two-sided):                  0.99   Kurtosis:                         3.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
#  Summary for  Albuquerque :
#                                        SARIMAX Results
# ==========================================================================================
# Dep. Variable:                        Albuquerque   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -453.114
# Date:                            Sat, 11 Dec 2021   AIC                            912.228
# Time:                                    15:53:02   BIC                            921.670
# Sample:                                07-14-2013   HQIC                           916.059
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.6846      0.098     -7.022      0.000      -0.876      -0.494
# ar.S.L104     -0.5316      0.083     -6.411      0.000      -0.694      -0.369
# sigma2         8.6947      1.153      7.544      0.000       6.436      10.954
# ===================================================================================
# Ljung-Box (L1) (Q):                  26.93   Jarque-Bera (JB):                 0.69
# Prob(Q):                              0.00   Prob(JB):                         0.71
# Heteroskedasticity (H):               1.15   Skew:                             0.15
# Prob(H) (two-sided):                  0.61   Kurtosis:                         2.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
#  Summary for  Miami :
#                                        SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Miami   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -362.224
# Date:                            Sat, 11 Dec 2021   AIC                            730.449
# Time:                                    15:53:02   BIC                            739.891
# Sample:                                07-14-2013   HQIC                           734.280
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.8873      0.099     -8.918      0.000      -1.082      -0.692
# ar.S.L104     -0.2922      0.116     -2.516      0.012      -0.520      -0.065
# sigma2         3.0871      0.378      8.174      0.000       2.347       3.827
# ===================================================================================
# Ljung-Box (L1) (Q):                  17.49   Jarque-Bera (JB):               103.80
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.27   Skew:                             0.07
# Prob(H) (two-sided):                  0.37   Kurtosis:                         6.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
#  Summary for  Minneapolis :
#                                        SARIMAX Results
# ==========================================================================================
# Dep. Variable:                        Minneapolis   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -542.312
# Date:                            Sat, 11 Dec 2021   AIC                           1090.624
# Time:                                    15:53:02   BIC                           1100.067
# Sample:                                07-14-2013   HQIC                          1094.455
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.6089      0.101     -6.021      0.000      -0.807      -0.411
# ar.S.L104     -0.2820      0.118     -2.391      0.017      -0.513      -0.051
# sigma2        28.2390      3.354      8.420      0.000      21.666      34.812
# ===================================================================================
# Ljung-Box (L1) (Q):                  11.08   Jarque-Bera (JB):                 2.05
# Prob(Q):                              0.00   Prob(JB):                         0.36
# Heteroskedasticity (H):               0.80   Skew:                             0.02
# Prob(H) (two-sided):                  0.40   Kurtosis:                         3.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
#  Summary for  Denver :
#                                        SARIMAX Results
# ==========================================================================================
# Dep. Variable:                             Denver   No. Observations:                  225
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 52)   Log Likelihood                -503.524
# Date:                            Sat, 11 Dec 2021   AIC                           1013.048
# Time:                                    15:53:02   BIC                           1022.491
# Sample:                                07-14-2013   HQIC                          1016.880
#                                      - 10-29-2017
# Covariance Type:                           approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L52      -0.8056      0.088     -9.198      0.000      -0.977      -0.634
# ar.S.L104     -0.5278      0.087     -6.074      0.000      -0.698      -0.357
# sigma2        15.1976      2.019      7.528      0.000      11.241      19.155
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.90   Jarque-Bera (JB):                 5.71
# Prob(Q):                              0.00   Prob(JB):                         0.06
# Heteroskedasticity (H):               1.18   Skew:                            -0.18
# Prob(H) (two-sided):                  0.54   Kurtosis:                         3.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# Summary Observations:
#
# - P value should be less than 0.05 in order for SARIMA to be the best model choice.
# - AIC and BIC values are checked to help choose values. The model with the lowest AIC value is best.
# There are no specific acceptable values for AIC and BIC. These values are based on on Log likelihood, so your values will vary based on your dataset.
# - The AR coeff value shows that mean is reverting in opposite directions.

# %% [markdown]
# Bonus:
# What do GARCH and ARCH Stand for? Break down and explain each piece in the names. Explain the difference between the two. Create a GARCH and ARCH model on the same 5 cities from question 6. Explain and graph the results.
